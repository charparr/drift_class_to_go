# %%
# Notebook for Figure 7, Using Table 3 Data
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_context('paper')

# %%
# Read the results of the drift definition analysis
df = pd.read_csv('../../figs/fig_tabular_data/general_drift_census_results_adjusted.csv')
del df['Unnamed: 0']
df.head()
# Out:
#    Year Swath  Total Area $m^2$  Total Volume $m^3$  Mean Depth $m$  \
# 0  2015  CLPX      9.543821e+07          17190050.0           0.547
# 1  2018  CLPX      9.377544e+07          22564338.0           0.575
# 2  2013    HV      2.067741e+07           3737648.5           0.549
# 3  2015    HV      2.852744e+07           6047839.0           0.708
# 4  2012  CLPX      9.317448e+07           5601252.0           0.361
#
#    Std. Depth $m$  Snowdrift Depth Threshold $m$        %DA        %DV  \
# 0           0.313                           0.82  16.470161  32.909614
# 1           0.380                           0.86  18.277571  41.840148
# 2           0.294                           0.77  15.240035  32.911077
# 3           0.241                           0.85  18.648809  29.937246
# 4           0.242                           0.65   7.884398  20.135826
#
#    Total Drift Area $m^2$  Total Drift Volume $m^3$  Drift Intensity $m$  \
# ...

# %%
df['Drift Susceptibility $m$'] = df['Drift Intensity $m$']

# %%
df.head()
# Out:
#    Year Swath  Total Area $m^2$  Total Volume $m^3$  Mean Depth $m$  \
# 0  2015  CLPX      9.543821e+07          17190050.0           0.547
# 1  2018  CLPX      9.377544e+07          22564338.0           0.575
# 2  2013    HV      2.067741e+07           3737648.5           0.549
# 3  2015    HV      2.852744e+07           6047839.0           0.708
# 4  2012  CLPX      9.317448e+07           5601252.0           0.361
#
#    Std. Depth $m$  Snowdrift Depth Threshold $m$        %DA        %DV  \
# 0           0.313                           0.82  16.470161  32.909614
# 1           0.380                           0.86  18.277571  41.840148
# 2           0.294                           0.77  15.240035  32.911077
# 3           0.241                           0.85  18.648809  29.937246
# 4           0.242                           0.65   7.884398  20.135826
#
#    Total Drift Area $m^2$  Total Drift Volume $m^3$  Drift Intensity $m$  \
# ...

# %%
fig = plt.figure(figsize=(8,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122, sharey = ax1)

# Tell pointplot to plot on ax1 with the ax argument
sns.catplot(x="Swath", y='Drift Susceptibility $m$',
            kind="box", data=df, ax=ax1)

# Tell the factorplot to plot on ax2 with the ax argument
# Also store the FacetGrid in 'g'

sns.catplot(x="Year", y="Drift Susceptibility $m$",
                hue="Swath", kind="point", data=df, ax=ax2)

ax2.yaxis.set_visible(False)

# Close the FacetGrid figure which we don't need (g.fig)
fig.subplots_adjust(wspace=0)
plt.close()
plt.close()
plt.savefig('../../figs/pngs/f7_drift_census_drift_susceptibility_box_and_line.png',
            dpi=200, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122, sharey = ax1)

# Tell pointplot to plot on ax1 with the ax argument
sns.catplot(x="Swath", y='Drift Volume / Drift Area (Avg. Drift Depth) $m$',
            kind="box", data=df, ax=ax1)

# Tell the factorplot to plot on ax2 with the ax argument
# Also store the FacetGrid in 'g'

sns.catplot(x="Year", y='Drift Volume / Drift Area (Avg. Drift Depth) $m$',
                hue="Swath", kind="point", data=df, ax=ax2)

ax2.yaxis.set_visible(False)

# Close the FacetGrid figure which we don't need (g.fig)
fig.subplots_adjust(wspace=0)
plt.close()
plt.close()
plt.savefig('../../figs/pngs/f7_drift_census_ndv_aka_avgdriftdepth_box_and_line.png',
            dpi=200, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8,8))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222, sharey = ax1)
ax3 = fig.add_subplot(223, sharex = ax1)
ax4 = fig.add_subplot(224, sharey = ax3, sharex=ax2)

sns.catplot(x="Swath", y='Drift Susceptibility $m$',
            kind="box", data=df, ax=ax1)

sns.catplot(x="Year", y="Drift Susceptibility $m$",
                hue="Swath", kind="point", data=df, ax=ax2)

sns.catplot(x="Swath", y='Drift Volume / Drift Area (Avg. Drift Depth) $m$',
            kind="box", data=df, ax=ax3)

sns.catplot(x="Year", y='Drift Volume / Drift Area (Avg. Drift Depth) $m$',
                hue="Swath", kind="point", data=df, ax=ax4)

ax1.xaxis.set_visible(False)
ax2.yaxis.set_visible(False)
ax2.xaxis.set_visible(False)
ax4.yaxis.set_visible(False)

# Close the FacetGrid figure which we don't need (g.fig)
fig.subplots_adjust(wspace=0)
fig.subplots_adjust(wspace=0,hspace=0)
plt.close()
plt.close()
plt.close()
plt.close()

plt.savefig('../../figs/pngs/f7_drift_census_ndv_aka_avgdriftdepth_drifty_suscep_2x2_box_and_line.png',
            dpi=200, bbox_inches='tight')
