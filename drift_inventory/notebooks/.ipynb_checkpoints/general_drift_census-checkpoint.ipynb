# %%
import rasterio
import numpy as np
import pandas as pd
import re
import glob
from sklearn import linear_model
import seaborn as sns
import matplotlib.pyplot as plt
np.warnings.filterwarnings('ignore')

# %%
def dir_of_geotiffs_to_dict(target):
    """
    Open and read all geotiifs in a target directory. Raster data stored
    as NumPy arrays in a dictionary. Metadata retained.

    Args:
        target (str): path to directory containing geotiffs

    Returns:
        rstr_dict (dict): dictionary with a key for each GeoTIFF
        Each GeoTIFF key has two sub-keys, "arr" and "meta" that
        store the raster data and metadata.
    Raises:
        Exception: description
    """
    rstr_dict = {}
    file_list = glob.glob(str(target) + '*.tif')

    for f in file_list:
        rstr_dict[f] = {}
       
        src = rasterio.open(f)
        rstr_dict[f]['arr'] = src.read(1)
        rstr_dict[f]['meta'] = src.meta
        rstr_dict[f]['profile'] = src.profile
        src.close()
        
    print('%i GeoTIFFs found.' % len (rstr_dict))  
    return rstr_dict


def replace_raster_nodata_with_array_nan_for_raster_dict(d):
        
    for k in d.keys():
        nodata = d[k]['meta']['nodata']
        d[k]['arr'][d[k]['arr'] == nodata] = np.nan
        d[k]['arr'][d[k]['arr'] < -1.0] = np.nan
        d[k]['arr'][d[k]['arr'] > 15.0] = np.nan
    return d
          
    
def compute_stats_for_raster_dict(d):
    
    for k in d.keys():
        d[k]['mu'] = np.nanmean(d[k]['arr']).round(3)
        d[k]['sigma'] = np.nanstd(d[k]['arr']).round(3)
        d[k]['CV'] = (d[k]['sigma'] / d[k]['mu']).round(3)
    return d

def tag_rasters_with_year_data_for_raster_dict(d):
    
    for k in d.keys():
        d[k]['year'] = re.findall('(\d{4})', k)[0]
    return d

def tag_rasters_with_swath_for_raster_dict(d):
    
    for k in d.keys():
        d[k]['swath'] = k.split('/')[-1].split('_')[0].upper()
    return d


def compute_total_area_for_rasters_in_dict(d):
    
    for k in d.keys():
        pixel_size = d[k]['meta']['transform'][0]
        total_area = (~np.isnan(d[k]['arr'])).sum() * pixel_size
        d[k]['total area m^2'] = total_area
    return d
        
def compute_total_volume_for_rasters_in_dict(d):
    
    for k in d.keys():
        pixel_size = d[k]['meta']['transform'][0]
        total_volume = np.nansum((~np.isnan(d[k]['arr'])) * d[k]['arr'] * pixel_size)
        d[k]['total volume m^3'] = total_volume
    return d

def generate_test_thresholds(d, start, stop, increment):
    # Compute test snow depth thresholds.
    # start, e.g. 0.8 = 80% of mean depth,
    # stop, e.g. 2.2 = 220% of mean depth,
    # increment, e.g. 0.1 = test at 10% steps between start and stop
    
    for k in d.keys():
        d[k]['test thresholds'] = np.round(np.arange(start, stop, increment) * d[k]['mu'], 2) 
    return d

def compute_area_and_volume_where_depth_exceeds_threshold(d):
    
    for k in d.keys():
 
        d[k]['pct. area results'] = []
        d[k]['pct. volume results'] = []
        d[k]['area results m^2'] = []
        d[k]['volume results m^3'] = []
        
        for thresh in d[k]['test thresholds']:
        
            # Create sub-dict for each test threshold
            thresh_k = str(thresh) + ' m threshold'
            d[k][thresh_k] = {}
            # Compute binary exceedance mask for each threshold
            drift_mask = (d[k]['arr'] > thresh)
            # Compute snow depth map where mask is 'True' aka depth > threshold
            exceeding_depth_values = drift_mask * d[k]['arr']
            # Set masked out depth values to nan so they can be ignored
            exceeding_depth_values[exceeding_depth_values == 0] = np.nan
            # Compute Area Exceeding Threshold (i.e. count number of pixels), pixel size=1
            d[k][thresh_k]['drift area m^2'] = int(np.nansum(exceeding_depth_values))
            d[k][thresh_k]['pct. drift area'] = (d[k][thresh_k]['drift area m^2'] / d[k]['total area m^2']) * 100
            # # Compute Volume Exceeding Threshold (i.e. sum of pixel intensities), pixel size=1
            d[k][thresh_k]['drift volume m^3'] = np.nansum(exceeding_depth_values * d[k]['arr'])
            d[k][thresh_k]['pct. drift volume'] = (d[k][thresh_k]['drift volume m^3'] / d[k]['total volume m^3']) * 100
            d[k]['pct. area results'].append(d[k][thresh_k]['pct. drift area'])
            d[k]['pct. volume results'].append(d[k][thresh_k]['pct. drift volume'])
            d[k]['area results m^2'].append(d[k][thresh_k]['drift area m^2'])
            d[k]['volume results m^3'].append(d[k][thresh_k]['drift volume m^3'])
                            
    return d

def compute_pct_volume_pct_area_difference(d):
    
    for k in d.keys():
        d[k]['pct. volume-area difference'] = [i - j for i, j in zip(d[k]['pct. volume results'],
                                                                     d[k]['pct. area results'])]
    return d
            
def compute_slope_of_pct_volume_pct_area_difference(d):
    
    for k in d.keys():
        d[k]['slope of pct. volume-area difference'] = np.gradient(d[k]['pct. volume-area difference'])
    return d

def find_min_of_slope_of_pct_volume_pct_area_difference(d):
    
    for k in d.keys():
        d[k]['min. of slope of pct. volume-area difference'] = d[k]['slope of pct. volume-area difference'].min()
        d[k]['index of min. of slope of pct. volume-area difference'] = np.argmin(d[k]['slope of pct. volume-area difference'])
    return d

def find_snowdrift_threshold(d):
    
    for k in d.keys():
        d[k]['snowdrift depth threshold m'] = d[k]['test thresholds'][d[k]['index of min. of slope of pct. volume-area difference']]
    return d

def find_snowdrift_areas_and_volumes(d):
    
    for k in d.keys():
        d[k]['pct. snowdrift area'] = d[k]['pct. area results'][d[k]['index of min. of slope of pct. volume-area difference']]
        d[k]['pct. snowdrift volume'] = d[k]['pct. volume results'][d[k]['index of min. of slope of pct. volume-area difference']]
        d[k]['total snowdrift area m^2'] = d[k]['area results m^2'][d[k]['index of min. of slope of pct. volume-area difference']]
        d[k]['total snowdrift volume m^3'] = d[k]['volume results m^3'][d[k]['index of min. of slope of pct. volume-area difference']]
    
    return d

def compute_area_normalized_drift_volume(d):
    
    for k in d.keys():
        d[k]['area normalized snowdrift volume m^3/m^2'] = d[k]['total snowdrift volume m^3'] / d[k]['total area m^2']
    return d

def recompute_from_new_threshold(d):
    # assuming user has changed the threshold
    for k in d.keys():
        drift_mask = (d[k]['arr'] > d[k]['snowdrift depth threshold m'])
        # Compute snow depth map where mask is 'True' aka depth > threshold
        exceeding_depth_values = drift_mask * d[k]['arr']
        # Set masked out depth values to nan so they can be ignored
        exceeding_depth_values[exceeding_depth_values == 0] = np.nan
        # Compute Area Exceeding Threshold (i.e. count number of pixels), pixel size=1
        d[k]['total snowdrift area m^2'] = int(np.nansum(exceeding_depth_values))
        d[k]['pct. snowdrift area'] = (d[k]['total snowdrift area m^2'] / d[k]['total area m^2']) * 100
        # Compute Volume Exceeding Threshold (i.e. sum of pixel intensities), pixel size=1
        d[k]['total snowdrift volume m^3'] = np.nansum(exceeding_depth_values * d[k]['arr'])
        d[k]['pct. snowdrift volume'] = (d[k]['total snowdrift volume m^3'] / d[k]['total volume m^3']) * 100
    return d

def dict_to_df(d):
    years = []
    swaths = []
    total_areas = []
    total_volumes = []
    mus = []
    sigmas = []
    drift_depth_thresholds = []
    pct_drift_areas = []
    pct_drift_volumes = []
    total_drift_areas = []
    total_drift_volumes = []
    drift_intensities = []

    for k in d.keys():

        swaths.append(d[k]['swath'])
        years.append(d[k]['year'])
        total_areas.append(d[k]['total area m^2'])
        total_volumes.append(d[k]['total volume m^3'])
        mus.append(d[k]['mu'])
        sigmas.append(d[k]['sigma'])
        drift_depth_thresholds.append(d[k]['snowdrift depth threshold m'])
        pct_drift_areas.append(d[k]['pct. snowdrift area'])
        pct_drift_volumes.append(d[k]['pct. snowdrift volume'])
        total_drift_areas.append(d[k]['total snowdrift area m^2'])
        total_drift_volumes.append(d[k]['total snowdrift volume m^3'])
        drift_intensities.append(d[k]['area normalized snowdrift volume m^3/m^2'])

    df = pd.DataFrame([years, swaths, total_areas, total_drift_volumes, mus, sigmas,
                      drift_depth_thresholds, pct_drift_areas, pct_drift_volumes,
                      total_drift_areas, total_drift_volumes,
                      drift_intensities]).T
    df.columns = ['Year', 'Swath', 'Total Area $m^2$', 'Total Volume $m^3$',
                  'Mean Depth $m$', 'Std. Depth $m$',
                  'Snowdrift Depth Threshold $m$', '%DA', '%DV',
                  'Total Drift Area $m^2$', 'Total Drift Volume $m^3$',
                  'Drift Intensity $m$']
    return df

# %%
snow_d = dir_of_geotiffs_to_dict('../../snow_depth_maps/')
snow_d = replace_raster_nodata_with_array_nan_for_raster_dict(snow_d)
snow_d = compute_stats_for_raster_dict(snow_d)
snow_d = tag_rasters_with_year_data_for_raster_dict(snow_d)
snow_d = tag_rasters_with_swath_for_raster_dict(snow_d)
snow_d = compute_total_area_for_rasters_in_dict(snow_d)
snow_d = compute_total_volume_for_rasters_in_dict(snow_d)
snow_d = generate_test_thresholds(snow_d, 0.8, 2.3, 0.1)
snow_d = compute_area_and_volume_where_depth_exceeds_threshold(snow_d)
snow_d = compute_pct_volume_pct_area_difference(snow_d)
snow_d = compute_slope_of_pct_volume_pct_area_difference(snow_d)
snow_d = find_min_of_slope_of_pct_volume_pct_area_difference(snow_d)
snow_d = find_snowdrift_threshold(snow_d)
snow_d = find_snowdrift_areas_and_volumes(snow_d)
snow_d = compute_area_normalized_drift_volume(snow_d)
# Out:
# 12 GeoTIFFs found.

# %%
for k in snow_d.keys():
    print(k)
    print(snow_d[k]['swath'])  
    print('Snowdrift depth threshold: %f m' % snow_d[k]['snowdrift depth threshold m'])
    print('Percent Area Covered by Snowdrift: %f' % snow_d[k]['pct. snowdrift area'])
    print('Percent Volume Stockpiled by Snowdrift: %f' % snow_d[k]['pct. snowdrift volume'])
    print('Area Normalized Snowdrift Intensity [m]: %f' % snow_d[k]['area normalized snowdrift volume m^3/m^2'])
    print('---')
# Out:
# ../../snow_depth_maps/clpx_depth_098_2015_corrected_0.36_m.tif
# CLPX
# Snowdrift depth threshold: 0.820000 m
# Percent Area Covered by Snowdrift: 16.470161
# Percent Volume Stockpiled by Snowdrift: 32.909614
# Area Normalized Snowdrift Intensity [m]: 0.180117
# ---
# ../../snow_depth_maps/clpx_depth_105_2018_corrected_0.25_m.tif
# CLPX
# Snowdrift depth threshold: 0.860000 m
# Percent Area Covered by Snowdrift: 18.277571
# Percent Volume Stockpiled by Snowdrift: 41.840148
# Area Normalized Snowdrift Intensity [m]: 0.240621
# ---
# ../../snow_depth_maps/hv_depth_103_2013_corrected_-0.03_m.tif
# HV
# Snowdrift depth threshold: 0.770000 m
# Percent Area Covered by Snowdrift: 15.240035
# Percent Volume Stockpiled by Snowdrift: 32.911077
# Area Normalized Snowdrift Intensity [m]: 0.180760
# ---
# ../../snow_depth_maps/hv_depth_098_2015_corrected_0.18_m.tif
# HV
# Snowdrift depth threshold: 0.850000 m
# Percent Area Covered by Snowdrift: 18.648809
# Percent Volume Stockpiled by Snowdrift: 29.937246
# Area Normalized Snowdrift Intensity [m]: 0.212001
# ---
# ../../snow_depth_maps/clpx_depth_106_2012_corrected_0.16_m.tif
# CLPX
# Snowdrift depth threshold: 0.650000 m
# Percent Area Covered by Snowdrift: 7.884398
# Percent Volume Stockpiled by Snowdrift: 20.135826
# Area Normalized Snowdrift Intensity [m]: 0.072642
# ---
# ../../snow_depth_maps/clpx_depth_101_2017_corrected_0.4_m.tif
# CLPX
# Snowdrift depth threshold: 0.750000 m
# Percent Area Covered by Snowdrift: 13.447058
# Percent Volume Stockpiled by Snowdrift: 27.874511
# Area Normalized Snowdrift Intensity [m]: 0.139055
# ---
# ../../snow_depth_maps/hv_depth_107_2012_corrected_-0.04_m.tif
# HV
# Snowdrift depth threshold: 0.720000 m
# Percent Area Covered by Snowdrift: 12.274849
# Percent Volume Stockpiled by Snowdrift: 30.178854
# Area Normalized Snowdrift Intensity [m]: 0.145484
# ---
# ../../snow_depth_maps/hv_depth_102_2017_corrected_-0.05_m.tif
# HV
# Snowdrift depth threshold: 0.800000 m
# Percent Area Covered by Snowdrift: 13.876162
# Percent Volume Stockpiled by Snowdrift: 32.746124
# Area Normalized Snowdrift Intensity [m]: 0.175117
# ---
# ../../snow_depth_maps/hv_depth_096_2016_corrected_0.00_m.tif
# HV
# Snowdrift depth threshold: 0.630000 m
# Percent Area Covered by Snowdrift: 15.358482
# Percent Volume Stockpiled by Snowdrift: 25.392744
# Area Normalized Snowdrift Intensity [m]: 0.133036
# ---
# ../../snow_depth_maps/clpx_depth_096_2016_corrected_0.38_m.tif
# CLPX
# Snowdrift depth threshold: 0.650000 m
# Percent Area Covered by Snowdrift: 11.918545
# Percent Volume Stockpiled by Snowdrift: 23.103981
# Area Normalized Snowdrift Intensity [m]: 0.106954
# ---
# ../../snow_depth_maps/hv_depth_103_2018_corrected_-0.08_m.tif
# HV
# Snowdrift depth threshold: 0.730000 m
# Percent Area Covered by Snowdrift: 16.977822
# Percent Volume Stockpiled by Snowdrift: 41.878498
# Area Normalized Snowdrift Intensity [m]: 0.204508
# ---
# ../../snow_depth_maps/clpx_depth_102_2013_corrected_0.21_m.tif
# CLPX
# Snowdrift depth threshold: 0.680000 m
# Percent Area Covered by Snowdrift: 13.781462
# Percent Volume Stockpiled by Snowdrift: 22.384386
# Area Normalized Snowdrift Intensity [m]: 0.117654
# ---

# %%
# 2012 and 2013 have smaller areal coverages...
for k in snow_d.keys():
    print(snow_d[k]['swath'], snow_d[k]['year'], snow_d[k]['total area m^2'] / 1000000)
    print('---')
# Out:
# CLPX 2015 95.438206
# ---
# CLPX 2018 93.775436
# ---
# HV 2013 20.677406
# ---
# HV 2015 28.527441
# ---
# CLPX 2012 77.107271
# ---
# CLPX 2017 94.273242
# ---
# HV 2012 18.94688
# ---
# HV 2017 27.830931
# ---
# HV 2016 26.255636
# ---
# CLPX 2016 93.209758
# ---
# HV 2018 27.939974
# ---
# CLPX 2013 78.740526
# ---

# %%
df = dict_to_df(snow_d)
df
# Out:
#     Year Swath Total Area $m^2$ Total Volume $m^3$ Mean Depth $m$  \
# 0   2015  CLPX      9.54382e+07        1.71900e+07          0.547
# 1   2018  CLPX      9.37754e+07        2.25643e+07          0.575
# 2   2013    HV      2.06774e+07        3.73765e+06          0.549
# 3   2015    HV      2.85274e+07        6.04784e+06          0.708
# 4   2012  CLPX      7.71073e+07        5.60125e+06          0.361
# 5   2017  CLPX      9.42732e+07        1.31092e+07          0.499
# 6   2012    HV      1.89469e+07        2.75646e+06          0.482
# 7   2017    HV      2.78309e+07        4.87366e+06          0.535
# 8   2016    HV      2.62556e+07        3.49294e+06          0.524
# 9   2016  CLPX      9.32098e+07        9.96912e+06          0.463
# 10  2018    HV        2.794e+07        5.71394e+06          0.488
# 11  2013  CLPX      7.87405e+07        9.26415e+06          0.526
#
#    Std. Depth $m$ Snowdrift Depth Threshold $m$      %DA      %DV  \
# 0           0.313                          0.82  16.4702  32.9096
# 1            0.38                          0.86  18.2776  41.8401
# 2           0.294                          0.77    15.24  32.9111
# 3           0.241                          0.85  18.6488  29.9372
# 4           0.242                          0.65   7.8844  20.1358
# 5           0.271                          0.75  13.4471  27.8745
# 6           0.284                          0.72  12.2748  30.1789
# 7           0.309                           0.8  13.8762  32.7461
# 8           0.204                          0.63  15.3585  25.3927
# 9           0.224                          0.65  11.9185   23.104
# 10          0.347                          0.73  16.9778  41.8785
# 11          0.202                          0.68  13.7815  22.3844
#
#    Total Drift Area $m^2$ Total Drift Volume $m^3$ Drift Intensity $m$
# 0                15718826              1.71900e+07            0.180117
# 1                17139872              2.25643e+07            0.240621
# 2                 3151244              3.73765e+06             0.18076
# 3                 5320028              6.04784e+06            0.212001
# 4                 6079444              5.60125e+06           0.0726423
# 5                12676978              1.31092e+07            0.139055
# 6                 2325701              2.75646e+06            0.145484
# 7                 3861865              4.87366e+06            0.175117
# 8                 4032467              3.49294e+06            0.133036
# 9                11109247              9.96912e+06            0.106954
# 10                4743599              5.71394e+06            0.204508
# 11               10851596              9.26415e+06            0.117654

# %%
# This is not an "apples to apples" comparison
# We are missing the south end of CLPX in 2012 and 2013.
# How can we account for it?
# We have the south end in 2015 on...
# Read them to a dictionary and do same analysis as above...

clpx_s = dir_of_geotiffs_to_dict('../../south_end_clpx/')
clpx_s = replace_raster_nodata_with_array_nan_for_raster_dict(clpx_s)
clpx_s = compute_stats_for_raster_dict(clpx_s)
clpx_s = tag_rasters_with_year_data_for_raster_dict(clpx_s)
clpx_s = tag_rasters_with_swath_for_raster_dict(clpx_s)
clpx_s = compute_total_area_for_rasters_in_dict(clpx_s)
clpx_s = compute_total_volume_for_rasters_in_dict(clpx_s)
clpx_s = generate_test_thresholds(clpx_s, 0.8, 2.3, 0.1)
clpx_s = compute_area_and_volume_where_depth_exceeds_threshold(clpx_s)
clpx_s = compute_pct_volume_pct_area_difference(clpx_s)
clpx_s = compute_slope_of_pct_volume_pct_area_difference(clpx_s)
clpx_s = find_min_of_slope_of_pct_volume_pct_area_difference(clpx_s)
clpx_s = find_snowdrift_threshold(clpx_s)
clpx_s = find_snowdrift_areas_and_volumes(clpx_s)
clpx_s = compute_area_normalized_drift_volume(clpx_s)

clpx_s_df = dict_to_df(clpx_s)
clpx_s_df['Swath'] = 'CLPX S.'
clpx_s_df.sort_values('Year', inplace=True)
clpx_s_df.set_index('Year', inplace=True)

clpx_s_df
# Out:
# 4 GeoTIFFs found.
#         Swath Total Area $m^2$ Total Volume $m^3$ Mean Depth $m$  \
# Year
# 2015  CLPX S.      1.65292e+07        4.21894e+06          0.708
# 2016  CLPX S.      1.55367e+07        1.95994e+06          0.505
# 2017  CLPX S.      1.61473e+07        2.03226e+06          0.427
# 2018  CLPX S.      1.60557e+07        3.09869e+06          0.571
#
#      Std. Depth $m$ Snowdrift Depth Threshold $m$      %DA      %DV  \
# Year
# 2015           0.34                          0.99       20   36.055
# 2016          0.274                          0.76  12.4302  25.0025
# 2017          0.292                          0.73  12.6423  29.4548
# 2018          0.384                          0.97   14.521  33.7947
#
#      Total Drift Area $m^2$ Total Drift Volume $m^3$ Drift Intensity $m$
# Year
# 2015                3305831              4.21894e+06            0.255242
# 2016                1931244              1.95994e+06            0.126149
# 2017                2041387              2.03226e+06            0.125858
# 2018                2331456              3.09869e+06            0.192996

# %%
# Replace computed south section thresholds with original threshold from full section
# Then recompute

clpx_s['../../south_end_clpx/s_endclpx_depth_098_2015.tif']['snowdrift depth threshold m'] = 0.82
clpx_s['../../south_end_clpx/s_endclpx_depth_096_2016.tif']['snowdrift depth threshold m'] = 0.65
clpx_s['../../south_end_clpx/s_endclpx_depth_101_2017.tif']['snowdrift depth threshold m'] = 0.75
clpx_s['../../south_end_clpx/s_endclpx_depth_105_2018.tif']['snowdrift depth threshold m'] = 0.86

clpx_s = recompute_from_new_threshold(clpx_s)
clpx_s = compute_area_normalized_drift_volume(clpx_s)

clpx_s_df2 = dict_to_df(clpx_s)
clpx_s_df2['Swath'] = 'CLPX S.'
clpx_s_df2.sort_values('Year', inplace=True)
clpx_s_df2.set_index('Year', inplace=True)

clpx_s_df2
# Out:
#         Swath Total Area $m^2$ Total Volume $m^3$ Mean Depth $m$  \
# Year
# 2015  CLPX S.      1.65292e+07        6.89457e+06          0.708
# 2016  CLPX S.      1.55367e+07        2.99141e+06          0.505
# 2017  CLPX S.      1.61473e+07        1.92312e+06          0.427
# 2018  CLPX S.      1.60557e+07        4.13702e+06          0.571
#
#      Std. Depth $m$ Snowdrift Depth Threshold $m$      %DA      %DV  \
# Year
# 2015           0.34                          0.82  37.9519   58.921
# 2016          0.274                          0.65  21.8841  38.1608
# 2017          0.292                          0.75  11.7289  27.8731
# 2018          0.384                          0.86  21.6111  45.1188
#
#      Total Drift Area $m^2$ Total Drift Volume $m^3$ Drift Intensity $m$
# Year
# 2015                6273137              6.89457e+06            0.417116
# 2016                3400058              2.99141e+06            0.192539
# 2017                1893891              1.92312e+06            0.119099
# 2018                3469814              4.13702e+06            0.257666

# %%
clpx_2015_on = df.copy(deep=True)[df['Swath'] == 'CLPX']
clpx_2015_on.sort_values('Year', inplace=True)
clpx_2015_on = clpx_2015_on.copy(deep=True).iloc[2:]
clpx_2015_on.set_index('Year', inplace=True)
clpx_2015_on
# Out:
#      Swath Total Area $m^2$ Total Volume $m^3$ Mean Depth $m$ Std. Depth $m$  \
# Year
# 2015  CLPX      9.54382e+07        1.71900e+07          0.547          0.313
# 2016  CLPX      9.32098e+07        9.96912e+06          0.463          0.224
# 2017  CLPX      9.42732e+07        1.31092e+07          0.499          0.271
# 2018  CLPX      9.37754e+07        2.25643e+07          0.575           0.38
#
#      Snowdrift Depth Threshold $m$      %DA      %DV Total Drift Area $m^2$  \
# Year
# 2015                          0.82  16.4702  32.9096               15718826
# 2016                          0.65  11.9185   23.104               11109247
# 2017                          0.75  13.4471  27.8745               12676978
# 2018                          0.86  18.2776  41.8401               17139872
#
#      Total Drift Volume $m^3$ Drift Intensity $m$
# Year
# 2015              1.71900e+07            0.180117
# 2016              9.96912e+06            0.106954
# 2017              1.31092e+07            0.139055
# 2018              2.25643e+07            0.240621

# %%
cols_for_lr = ['Total Area $m^2$', 'Total Drift Area $m^2$',
               'Total Drift Volume $m^3$', 'Drift Intensity $m$',
               'Mean Depth $m$', 'Std. Depth $m$']

clpx_full_df_for_lr = clpx_2015_on[cols_for_lr]
clpx_s_df_for_lr = clpx_s_df2[cols_for_lr]

clpx_full_df_for_lr.columns = ['Full Total Area $m^2$', 'Full Total Drift Area $m^2$',
                               'Full Total Drift Volume $m^3$', 'Full Drift Intensity $m$',
                               'Full Mean Depth $m$', 'Full Std. Depth $m$']

clpx_s_df_for_lr.columns = ['South Total Area $m^2$', 'South Total Drift Area $m^2$',
                            'South Total Drift Volume $m^3$', 'South Drift Intensity $m$',
                            'South Mean Depth $m$', 'South Std. Depth $m$']

lr_df = pd.concat([clpx_full_df_for_lr, clpx_s_df_for_lr], axis=1)
lr_df['Full - South Total Area Difference $m^2$'] = lr_df['Full Total Area $m^2$'] - lr_df['South Total Area $m^2$']
lr_df['Full - South Drift Volume Difference $m^3$'] = lr_df['Full Total Drift Volume $m^3$'] - lr_df['South Total Drift Volume $m^3$']
lr_df['Full - South Drift Area Difference $m^2$'] = lr_df['Full Total Drift Area $m^2$'] - lr_df['South Total Drift Area $m^2$']
lr_df['Full - South Mean Depth Difference $m$'] = lr_df['Full Mean Depth $m$'] - lr_df['South Mean Depth $m$']
lr_df['Full - South Std. Depth Difference $m$'] = lr_df['Full Std. Depth $m$'] - lr_df['South Std. Depth $m$']

lr_df
# Out:
#      Full Total Area $m^2$ Full Total Drift Area $m^2$  \
# Year
# 2015           9.54382e+07                    15718826
# 2016           9.32098e+07                    11109247
# 2017           9.42732e+07                    12676978
# 2018           9.37754e+07                    17139872
#
#      Full Total Drift Volume $m^3$ Full Drift Intensity $m$  \
# Year
# 2015                   1.71900e+07                 0.180117
# 2016                   9.96912e+06                 0.106954
# 2017                   1.31092e+07                 0.139055
# 2018                   2.25643e+07                 0.240621
#
#      Full Mean Depth $m$ Full Std. Depth $m$ South Total Area $m^2$  \
# Year
# 2015               0.547               0.313            1.65292e+07
# 2016               0.463               0.224            1.55367e+07
# 2017               0.499               0.271            1.61473e+07
# 2018               0.575                0.38            1.60557e+07
#
#      South Total Drift Area $m^2$ South Total Drift Volume $m^3$  \
# Year
# 2015                      6273137                    6.89457e+06
# 2016                      3400058                    2.99141e+06
# 2017                      1893891                    1.92312e+06
# 2018                      3469814                    4.13702e+06
#
#      South Drift Intensity $m$ South Mean Depth $m$ South Std. Depth $m$  \
# Year
# 2015                  0.417116                0.708                 0.34
# 2016                  0.192539                0.505                0.274
# 2017                  0.119099                0.427                0.292
# 2018                  0.257666                0.571                0.384
#
#      Full - South Total Area Difference $m^2$  \
# Year
# 2015                               7.8909e+07
# 2016                              7.76731e+07
# 2017                               7.8126e+07
# 2018                              7.77197e+07
#
#      Full - South Drift Volume Difference $m^3$  \
# Year
# 2015                                1.02955e+07
# 2016                                6.97771e+06
# 2017                                1.11861e+07
# 2018                                1.84273e+07
#
#      Full - South Drift Area Difference $m^2$  \
# Year
# 2015                                  9445689
# 2016                                  7709189
# 2017                                 10783087
# 2018                                 13670058
#
#      Full - South Mean Depth Difference $m$  \
# Year
# 2015                                 -0.161
# 2016                                 -0.042
# 2017                                  0.072
# 2018                             0.00400001
#
#      Full - South Std. Depth Difference $m$
# Year
# 2015                                 -0.027
# 2016                                  -0.05
# 2017                                 -0.021
# 2018                            -0.00400001

# %%
# Can we use the difference in amounts of snow volume and area to predict new drift volumes for the south
# ends of the swath missing in 2012 and 2013? 

# X = lr_df.copy(deep=True)[['Full - South Total Area Difference $m^2$',
#                            'Full - South Drift Volume Difference $m^3$']]

# X = lr_df.copy(deep=True)[['South Total Area $m^2$',
#                            'South Total Drift Volume $m^3$',
#                            'South Mean Depth $m$']]

X = lr_df.copy(deep=True)[['South Total Area $m^2$',
                           'South Total Drift Volume $m^3$',
                           'South Mean Depth $m$',
                           'South Std. Depth $m$']]

target = pd.DataFrame(lr_df.copy(deep=True), columns=['South Total Drift Volume $m^3$'])
y = target.copy(deep=True)['South Total Drift Volume $m^3$']

lm = linear_model.LinearRegression()
model = lm.fit(X, y)
predictions = lm.predict(X)

print(predictions)
print(lm.score(X, y))
print(lm.coef_)

clpx_to_predict = df.copy(deep=True)[df['Swath'] == 'CLPX']
clpx_to_predict.sort_values('Year', inplace=True)

clpx_to_predict = clpx_to_predict.copy().iloc[:2]
clpx_to_predict.set_index('Year', inplace=True)

# clpx_to_predict_lr = clpx_to_predict[['Total Area $m^2$',
#                                       'Total Drift Volume $m^3$',]]


clpx_to_predict_lr = clpx_to_predict[['Total Area $m^2$',
                                      'Total Drift Volume $m^3$',
                                      'Mean Depth $m$', 'Std. Depth $m$']]

clpx_2012_s_drift_volume_prediction, clpx_2013_s_drift_volume_prediction = lm.predict(clpx_to_predict_lr)

print(clpx_2012_s_drift_volume_prediction)
print(clpx_2013_s_drift_volume_prediction)
# Out:
# [6894570.5 2991410.5 1923121.  4137021. ]
# 1.0
# [ 4.04456567e-15  1.00000000e+00  5.62852149e-08 -8.07886638e-09]
# 5601252.000000233
# 9264148.000000237

# %%
#Can we also predict the south drift area?

X = lr_df.copy(deep=True)[['South Total Area $m^2$',
                           'South Total Drift Area $m^2$',
                           'South Mean Depth $m$',
                           'South Std. Depth $m$']]

target = pd.DataFrame(lr_df.copy(deep=True), columns=['South Total Drift Area $m^2$'])
y = target.copy(deep=True)['South Total Drift Area $m^2$']

lm = linear_model.LinearRegression()
model = lm.fit(X, y)
predictions = lm.predict(X)

print(predictions)
print(lm.score(X, y))
print(lm.coef_)

clpx_to_predict = df.copy(deep=True)[df['Swath'] == 'CLPX']
clpx_to_predict.sort_values('Year', inplace=True)

clpx_to_predict = clpx_to_predict.copy().iloc[:2]
clpx_to_predict.set_index('Year', inplace=True)

# clpx_to_predict_lr = clpx_to_predict[['Total Area $m^2$',
#                                       'Total Drift Volume $m^3$',]]


clpx_to_predict_lr = clpx_to_predict[['Total Area $m^2$',
                                      'Total Drift Area $m^2$',
                                      'Mean Depth $m$', 'Std. Depth $m$']]

clpx_2012_s_drift_area_prediction, clpx_2013_s_drift_area_prediction = lm.predict(clpx_to_predict_lr)

print(clpx_2012_s_drift_area_prediction)
print(clpx_2013_s_drift_area_prediction)
# Out:
# [6273137. 3400058. 1893891. 3469814.]
# 1.0
# [-1.63608683e-15  1.00000000e+00  4.09087896e-08 -3.00772240e-08]
# 6079443.99999989
# 10851595.999999885

# %%
# So now we use these predictions to update our original results
# We need to update the total area measured for CLPX 2012 and 2013
# We need to update the total volume for CLPX 2012 and 2013
# To update the total area measured:
# What is the mean area of the south chunk?
mean_clpx_s_area = lr_df['South Total Area $m^2$'].mean()
# print(mean_clpx_s_area)

# Add this amount (about 16 sq km) to the total area value for clpx in 2012 and 2013

adjusted_df = df.copy(deep=True)

# Indexing should be smarter but works for now
adjusted_df.at[4, 'Total Area $m^2$'] = df.at[4, 'Total Area $m^2$'] + mean_clpx_s_area
adjusted_df.at[11, 'Total Area $m^2$'] = df.at[11, 'Total Area $m^2$'] + mean_clpx_s_area

# Now we should do the same with the drift volume predictions
adjusted_df.at[4, 'Total Drift Volume $m^3$'] = df.at[4, 'Total Drift Volume $m^3$'] + clpx_2012_s_drift_volume_prediction
adjusted_df.at[11, 'Total Drift Volume $m^3$'] = df.at[11, 'Total Drift Volume $m^3$'] + clpx_2013_s_drift_volume_prediction

# And now we recompute the drift intensity
adjusted_df.at[4, 'Drift Intensity $m$'] = adjusted_df.at[4, 'Total Drift Volume $m^3$'] / adjusted_df.at[4, 'Total Area $m^2$']
adjusted_df.at[11, 'Drift Intensity $m$'] = adjusted_df.at[11, 'Total Drift Volume $m^3$'] / adjusted_df.at[11, 'Total Area $m^2$']

# Now we should do the same with the south drift area predictions
adjusted_df.at[4, 'Total Drift Area $m^2$'] = df.at[4, 'Total Drift Area $m^2$'] + clpx_2012_s_drift_area_prediction
adjusted_df.at[11, 'Total Drift Area $m^2$'] = df.at[11, 'Total Drift Area $m^2$'] + clpx_2013_s_drift_area_prediction

adjusted_df
# Out:
#     Year Swath Total Area $m^2$ Total Volume $m^3$ Mean Depth $m$  \
# 0   2015  CLPX      9.54382e+07        1.71900e+07          0.547
# 1   2018  CLPX      9.37754e+07        2.25643e+07          0.575
# 2   2013    HV      2.06774e+07        3.73765e+06          0.549
# 3   2015    HV      2.85274e+07        6.04784e+06          0.708
# 4   2012  CLPX      9.31745e+07        5.60125e+06          0.361
# 5   2017  CLPX      9.42732e+07        1.31092e+07          0.499
# 6   2012    HV      1.89469e+07        2.75646e+06          0.482
# 7   2017    HV      2.78309e+07        4.87366e+06          0.535
# 8   2016    HV      2.62556e+07        3.49294e+06          0.524
# 9   2016  CLPX      9.32098e+07        9.96912e+06          0.463
# 10  2018    HV        2.794e+07        5.71394e+06          0.488
# 11  2013  CLPX      9.48077e+07        9.26415e+06          0.526
#
#    Std. Depth $m$ Snowdrift Depth Threshold $m$      %DA      %DV  \
# 0           0.313                          0.82  16.4702  32.9096
# 1            0.38                          0.86  18.2776  41.8401
# 2           0.294                          0.77    15.24  32.9111
# 3           0.241                          0.85  18.6488  29.9372
# 4           0.242                          0.65   7.8844  20.1358
# 5           0.271                          0.75  13.4471  27.8745
# 6           0.284                          0.72  12.2748  30.1789
# 7           0.309                           0.8  13.8762  32.7461
# 8           0.204                          0.63  15.3585  25.3927
# 9           0.224                          0.65  11.9185   23.104
# 10          0.347                          0.73  16.9778  41.8785
# 11          0.202                          0.68  13.7815  22.3844
#
#    Total Drift Area $m^2$ Total Drift Volume $m^3$ Drift Intensity $m$
# 0                15718826              1.71900e+07            0.180117
# 1                17139872              2.25643e+07            0.240621
# 2                 3151244              3.73765e+06             0.18076
# 3                 5320028              6.04784e+06            0.212001
# 4             1.21589e+07              1.12025e+07            0.120231
# 5                12676978              1.31092e+07            0.139055
# 6                 2325701              2.75646e+06            0.145484
# 7                 3861865              4.87366e+06            0.175117
# 8                 4032467              3.49294e+06            0.133036
# 9                11109247              9.96912e+06            0.106954
# 10                4743599              5.71394e+06            0.204508
# 11            2.17032e+07              1.85283e+07             0.19543

# %%
adjusted_df['Drift Intensity $m$'] - df['Drift Intensity $m$']
# This is too small...use thresholds from original analysis
# Out:
# 0             0
# 1             0
# 2             0
# 3             0
# 4     0.0475891
# 5             0
# 6             0
# 7             0
# 8             0
# 9             0
# 10            0
# 11    0.0777761
# Name: Drift Intensity $m$, dtype: object

# %%
# Now let us compute drift volume per drift area...this average drift depth
adjusted_df['Drift Volume / Drift Area (Avg. Drift Depth) $m$'] = adjusted_df['Total Drift Volume $m^3$'] / adjusted_df['Total Drift Area $m^2$']
adjusted_df['Drift Volume / Drift Area (Avg. Drift Depth) $m$']
# Out:
# 0       1.0936
# 1      1.31648
# 2      1.18609
# 3      1.13681
# 4     0.921343
# 5      1.03409
# 6      1.18522
# 7        1.262
# 8     0.866205
# 9     0.897371
# 10     1.20456
# 11    0.853713
# Name: Drift Volume / Drift Area (Avg. Drift Depth) $m$, dtype: object

# %%
adjusted_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-95bb17d93bd1> in <module>
# ----> 1 adjusted_df.head()
#
# NameError: name 'adjusted_df' is not defined

# %%
adjusted_df.to_csv('../../thesis_text/figs/fig_tabular_data/general_drift_census_results_adjusted.csv')

# %%
# Linear Regression of Drift Area to Volume by Swath
from scipy.stats import linregress

clpx_x = adjusted_df[adjusted_df['Swath']=='CLPX']['Total Drift Area $m^2$'].values
clpx_y = adjusted_df[adjusted_df['Swath']=='CLPX']['Total Drift Volume $m^3$'].values

#type(clpx_y)
clpx_slope, clpx_intercept, clpx_rvalue, clpx_pvalue, clpx_stderr = linregress(clpx_x.astype(float), clpx_y.astype(float))

# %%
hv_x = adjusted_df[adjusted_df['Swath']=='HV']['Total Drift Area $m^2$'].values
hv_y = adjusted_df[adjusted_df['Swath']=='HV']['Total Drift Volume $m^3$'].values

#type(clpx_y)
hv_slope, hv_intercept, hv_rvalue, hv_pvalue, hv_stderr = linregress(hv_x.astype(float), hv_y.astype(float))

# %%
plt.scatter(clpx_x, clpx_y, label='CLPX')
plt.scatter(hv_x, hv_y, label='HV')

plt.plot(clpx_x, clpx_intercept + clpx_slope*clpx_x, 'blue', label=str(clpx_slope.round(3)) + '$\pm$' + str(clpx_stderr.round(2)))
plt.plot(hv_x, hv_intercept + hv_slope*hv_x, 'orange', label=str(hv_slope.round(3)) + '$\pm$' + str(hv_stderr.round(2)))
plt.legend()
plt.ylabel('Total Drift Volume $m^3$')
plt.xlabel('Total Drift Area $m^2$')
plt.savefig('../../thesis_text/figs/pngs/x_driftarea_y_driftvolume_linregress_by_swath.png', dpi=200, bbox_inches='tight')
# >>> plt.show()

# %%
print(hv_rvalue, clpx_rvalue)
# Out:
# 0.9051013856794599 0.7931461754328597

# %%
clpx_di_mean = adjusted_df[adjusted_df['Swath']=='CLPX']['Drift Intensity $m$'].mean()
hv_di_mean = adjusted_df[adjusted_df['Swath']=='HV']['Drift Intensity $m$'].mean()
clpx_di_std = adjusted_df[adjusted_df['Swath']=='CLPX']['Drift Intensity $m$'].std()
hv_di_std = adjusted_df[adjusted_df['Swath']=='HV']['Drift Intensity $m$'].std()

print(clpx_di_mean, clpx_di_std)
print(hv_di_mean, hv_di_std)
print(clpx_di_std / clpx_di_mean)
print(hv_di_std / hv_di_mean)
# Out:
# 0.16373474465115476 0.05081377214907436
# 0.17515075385582501 0.031320968303487344
# 0.31034202457966814
# 0.1788229146262718

# %%
import pandas as pd
df = pd.read_csv('../../thesis_text/figs/fig_tabular_data/general_drift_census_pretty.csv')
del df['Unnamed: 0']
df['%DA'] = df['%DA'].round(2)
df['%DV'] = df['%DV'].round(2)
df['Drift Intensity $m$'] = df['Drift Intensity $m$'].round(3)
df.rename(columns={'Drift Volume / Drift Area (Avg. Drift Depth) $m$':'Mean Drift Depth $m$'}, inplace=True)
df['Mean Drift Depth $m$'] = df['Mean Drift Depth $m$'].round(2)

df = df.sort_values(['Year', 'Swath'])
df.to_csv('../../thesis_text/figs/fig_tabular_data/general_drift_census_pretty_rounded.csv', index=False)

# %%
outtable = adjusted_df.copy()
del outtable['Mean Depth $m$']
del outtable['Std. Depth $m$']
del outtable['Total Volume $m^3$']
del outtable['Total Area $m^2$']

# %%
outtable['Total Drift Area $m^2$'] = outtable['Total Drift Area $m^2$'].astype(int)
outtable['Total Drift Volume $m^3$'] = outtable['Total Drift Volume $m^3$'].astype(int)
outtable.sort_values('Year', inplace=True)
#outtable
outtable.to_csv('../../thesis_text/figs/fig_tabular_data/general_drift_census_pretty.csv')

# %%
outtable['Drift Intensity $m$'].round(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'numpy.float64' object has no attribute 'rint'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-377c5e739d37> in <module>
# ----> 1 outtable['Drift Intensity $m$'].round(3)
#
# ~/miniconda3/envs/geo/lib/python3.7/site-packages/pandas/core/series.py in round(self, decimals, *args, **kwargs)
#    2341         """
#    2342         nv.validate_round(args, kwargs)
# -> 2343         result = com.values_from_object(self).round(decimals)
#    2344         result = self._constructor(result, index=self.index).__finalize__(self)
#    2345
#
# TypeError: loop of ufunc does not support argument 0 of type numpy.float64 which has no callable rint method

# %%
###############3333

# %%
# Now let's create masks using the found thresholds for a clpx and hv drift potential map

hvmasks = [d[k]['drift mask'] for k in d.keys() if 'hv' in k]
hv_drift_any_yr = np.logical_or.reduce(hvmasks)
hv_drift_all_yr = np.logical_or.reduce(hvmasks)
hv_drift_ct_yr = np.nansum(hvmasks, axis=0)


clpxmasks = [d[k]['drift mask'] for k in d.keys() if 'clpx' in k]
clpx_drift_any_yr = np.logical_or.reduce(clpxmasks)
clpx_drift_all_yr = np.logical_and.reduce(clpxmasks)
clpx_drift_ct_yr = np.nansum(clpxmasks, axis=0)

# %%
plt.figure(figsize=(16,10))
plt.imshow(clpx_drift_ct_yr > 2, cmap='gray', interpolation='none')

# %%
a = clpx_drift_ct_yr > 2

# %%
plt.figure(figsize=(16,10))
plt.imshow(c, cmap='gray', interpolation='none')

# %%
import fiona
import rasterio.features

mask = (hv_drift_ct_yr > 2).astype('uint8')
schema = {"geometry": "Polygon", "properties": {"value": "int"}}

shapes = rasterio.features.shapes(mask, transform=t)
# select the records from shapes where the value is 1,
# or where the mask was True
records = [{"geometry": geometry, "properties": {"value": value}}
            for (geometry, value) in shapes if value == 1]

# %%
plt.figure(figsize=(10,16))
plt.imshow(hv_drift_ct_yr > 2, cmap='gray', interpolation='none')

# %%
from dem_utils import write_geomorph
help(write_geomorph)

# %%
hv_profile = d['../depth_dDEMs/hv/corrected/hv_depth_096_2016_corrected_0.00_m.tif']['profile']
hv_profile

# %%
clpx_profile = d['../depth_dDEMs/clpx/corrected/clpx_depth_096_2016_corrected_0.38_m.tif']['profile']
clpx_profile

# %%
write_geomorph(arr=clpx_drift_ct_yr.astype('float32'),
               out_path='clpx_driftmask_ct_years.tif',
               tag='',
               profile=clpx_profile)

# %%
write_geomorph(arr=c.astype('float32'),
               out_path='clpx_driftmask_all_years_rmholeobj.tif',
               tag='',
               profile=clpx_profile)

# %%
write_geomorph(arr=clpx_drift_any_yr.astype('float32'),
               out_path='clpx_driftmask_any_years.tif',
               tag='',
               profile=clpx_profile)

# %%
write_geomorph(arr=hv_drift_any_yr.astype('float32'),
               out_path='hv_driftmask_any_years.tif',
               tag='',
               profile=hv_profile)

# %%
write_geomorph(arr=hv_drift_all_yr.astype('float32'),
               out_path='hv_driftmask_all_years.tif',
               tag='',
               profile=hv_profile)

# %%
write_geomorph(arr=hv_drift_ct_yr.astype('float32'),
               out_path='hv_driftmask_ct_years.tif',
               tag='',
               profile=hv_profile)
