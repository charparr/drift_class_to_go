# %%
import geopandas as gpd
import pandas as pd
import rasterio
import rasterstats as rs
import numpy as np
import sys
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
sys.path.insert(0, '../../snow_terrain_tiles/')
from dem_utils import recursive_rastersstats_to_dict

# %%
# Function to compute zonal raster statistics using rasterstats library
# for single shapefile and many rasters inside a single directory
# Returns geodataframe

def compute_drift_statistics(regx, shp):
    d = recursive_rastersstats_to_dict(regx, '*_corrected*')
    geodf = gpd.read_file(shp)
    stats=['mean', 'std', 'median', 'sum']

    for k in d.keys():

        col_name = str(d[k]['year'][0])

        zonal_d = (rs.zonal_stats(geodf, k,
                                 stats=stats))
        geodf[col_name] = zonal_d
        
        for st in stats:
    
            st_series = geodf[col_name].apply(lambda x: x.get(st))
            yr_st_name = col_name + '_' + st
            geodf[yr_st_name] = st_series

        del geodf[col_name]
        
    return geodf

# %%
# compute stats with our function. combine hv and clpx results
hv = compute_drift_statistics('../../depth_dDEMs/hv/', '../gis/hv_drifts.shp')
clpx = compute_drift_statistics('../../depth_dDEMs/clpx/', '../gis/clpx_drifts.shp')
geodf = pd.concat([hv, clpx], sort=False)
len(hv) + len(clpx) == len(geodf)
# Out:
# ../../snow_terrain_tiles/dem_utils.py:149: RuntimeWarning: invalid value encountered in less
#   arr[arr < -9999] = np.nan
# True

# %%
# Lots of NoData from 2012/2013 lidar acquisitions

geodf_15on = geodf.dropna(axis=1)
geodf_15on.columns
# Out:
# Index(['drift_type', 'study_area', 'geometry', '2015_mean', '2015_std',
#        '2015_median', '2015_sum', '2018_mean', '2018_std', '2018_median',
#        '2018_sum', '2016_mean', '2016_std', '2016_median', '2016_sum',
#        '2017_mean', '2017_std', '2017_median', '2017_sum'],
#       dtype='object')

# %%
# Get time series averages (e.g. mean of means)
all_means = geodf_15on.filter(regex='mean', axis=1)
all_std = geodf_15on.filter(regex='std', axis=1)
all_volumes = geodf_15on.filter(regex='sum', axis=1)
all_meds = geodf_15on.filter(regex='median', axis=1)

ts_mean = all_means.mean(axis=1)
ts_std = all_std.mean(axis=1)
ts_vol = all_volumes.mean(axis=1)
ts_med = all_meds.mean(axis=1)

summary_df = pd.DataFrame()
summary_df['Drift Type'] = geodf_15on.drift_type
summary_df['Study Area'] = [s.upper() for s in geodf_15on.study_area]
summary_df['Drift Area [m^2]'] = geodf_15on.area

summary_df['Mean Drift Depth [m]'] = ts_mean
summary_df['Mean Drift Volume [m^3]'] = ts_vol
summary_df['Std. Drift Depth [m]'] = ts_std
summary_df['Median Drift Depth [m]'] = ts_med

summary_df['CV Drift Depth'] = ts_std / ts_mean
summary_df['Volume:Area Ratio'] = ts_vol / summary_df['Drift Area [m^2]']

summary_df.head(3)
# Out:
#    Drift Type Study Area  Drift Area [m^2]  Mean Drift Depth [m]  \
# 0  watertrack         HV      23636.367493              0.776019
# 1  watertrack         HV       9069.760465              0.777382
# 2  watertrack         HV      27802.663732              1.093303
#
#    Mean Drift Volume [m^3]  Std. Drift Depth [m]  Median Drift Depth [m]  \
# 0             18053.440430              0.171731                0.791751
# 1              7044.636963              0.203242                0.755424
# 2             30428.813477              0.414733                1.105991
#
#    CV Drift Depth  Volume:Area Ratio
# 0        0.221298           0.763799
# 1        0.261444           0.776717
# 2        0.379340           1.094457

# %%
sns.set_context('paper')
ax = sns.scatterplot(x="Drift Type", y="CV Drift Depth", hue='Study Area', data=summary_df)
plt.savefig('../figs/drift_type_x_cv_depth_y.png', dpi=300, bbox_inches='tight')

# %%
sns.catplot(x="Drift Type", y="Volume:Area Ratio", hue='Study Area',
            data=summary_df)
plt.axhline(y=1, c='r', ls='--', alpha=0.5)
plt.savefig('../figs/drift_type_x_volume_area_ratio_y.png', dpi=300, bbox_inches='tight')

# %%
summary_df.round(2).to_csv('../results/drift_classification_summary.csv', index=False)

# %%
summary_df['Volume:Area Ratio'].max()
# Out:
# 1.4780299278779883

# %%
summary_df.groupby(['Study Area','Drift Type']).mean()
summary_df.groupby(['Study Area','Drift Type']).mean().round(2).to_csv('../results/drift_class_grp_mean.csv')

# %%
d = {}

fig = plt.subplots(nrows=2, ncols=3)

for i in summary_df['Drift Type'].unique():

    d[i] = {}
    driftclass = summary_df[summary_df['Drift Type']==i]
    x = driftclass["Drift Area [m^2]"]
    y = driftclass["Mean Drift Volume [m^3]"]
    d[i]['x'] = x
    d[i]['y'] = y
    
    gradient,intercept,r_value,p_value,std_err=stats.linregress(x,y)
    d[i]['Gradient'] = gradient.round(4)
    d[i]['Intercept'] = intercept.round(4)
    d[i]['R Value'] = r_value.round(5)
    d[i]['P Value'] = p_value.round(5)
    d[i]['Std. Error'] = std_err.round(4)
    
    #str1 = str("Gradient and intercept" + d[i]['Gradient'] + d[i]['Intercept'])
    print("Gradient and intercept",d[i]['Gradient'], d[i]['Intercept'])
    print("R-squared", d[i]['R Value'] ** 2)
    print("p-value", d[i]['P Value'])
   
    
    plt.figure(figsize=(8,5))
    plt.plot(x, y, 'o', c='#236192', label='original data')
    plt.plot(x, intercept + gradient * x, '#A6192E', label='fitted line')
    plt.ylabel("Snowdrift Volume m$3$")
    plt.xlabel("Snowdrift Area m$2$")
    plt.title(i)
    plt.legend()
    
    ax = plt.gca()
    txtstr = "y = " + str(d[i]['Gradient']) + 'x + ' + str(d[i]['Intercept'])
    ax.text(0.05, 0.75, txtstr, style='italic',
            transform=ax.transAxes,
            bbox={'facecolor':'#EFDBB2', 'alpha':0.5, 'pad':10})
    
    rvstr = "R-squared " + str(np.round(d[i]['R Value'] ** 2, 4))

    ax.text(0.05, 0.64, rvstr, style='italic',
        transform=ax.transAxes,
        bbox={'facecolor':'#C7C9C7', 'alpha':0.5, 'pad':10})

    
    plt.show()
# Out:
# Gradient and intercept 1.0316 -858.6563
# R-squared 0.9638330625
# p-value 0.0
# Gradient and intercept 1.3314 -3459.4312
# R-squared 0.9952456644
# p-value 0.0
# Gradient and intercept 0.8574 8.5261
# R-squared 0.9775276900000001
# p-value 0.0
# Gradient and intercept 0.8796 -146.9145
# R-squared 0.9999600004
# p-value 0.0
# Gradient and intercept 1.2351 138.1116
# R-squared 0.9985205476000001
# p-value 0.0
# Gradient and intercept 1.5577 -938.6613
# R-squared 0.9958642849
# p-value 0.00011

# %%
d = {}

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(16,10))
j = 0

for i in summary_df['Drift Type'].unique():

    d[i] = {}
    driftclass = summary_df[summary_df['Drift Type']==i]
    x = driftclass["Drift Area [m^2]"]
    y = driftclass["Mean Drift Volume [m^3]"]
    d[i]['x'] = x
    d[i]['y'] = y
    
    gradient,intercept,r_value,p_value,std_err=stats.linregress(x,y)
    d[i]['Gradient'] = gradient.round(4)
    d[i]['Intercept'] = intercept.round(4)
    d[i]['R Value'] = r_value.round(5)
    d[i]['P Value'] = p_value.round(5)
    d[i]['Std. Error'] = std_err.round(4)
    
    #plt.figure(figsize=(8,5))
    if j <= 2:
        ax = axes[0, j]
    else:
        ax = axes[1, j - 3]
        
    ax.plot(x, y, 'o', c='#236192', label='original data')
    ax.plot(x, intercept + gradient * x, '#A6192E', label='fitted line')
    ax.set_ylabel("Snowdrift Volume m$^3$")
    ax.set_xlabel("Snowdrift Area m$^2$")
    ax.set_title(i)
    ax.legend()
    
    txtstr = "y = " + str(d[i]['Gradient']) + 'x + ' + str(d[i]['Intercept'])
    ax.text(0.05, 0.75, txtstr, style='italic',
            transform=ax.transAxes,
            bbox={'facecolor':'#D7D2CB', 'alpha':0.5, 'pad':10})
    
    rvstr = "R-squared " + str(np.round(d[i]['R Value'] ** 2, 4))

    ax.text(0.05, 0.63, rvstr, style='italic',
        transform=ax.transAxes,
        bbox={'facecolor':'#C7C9C7', 'alpha':0.5, 'pad':10})

    j+=1
plt.subplots_adjust(wspace=0.25, hspace=0.25)
plt.savefig('../figs/snowdrift_class_area_volume_linreg_3x2.png',
            facecolor='#EFDBB2', dpi=300, bbox_inches='tight')

# slope is drift SWE
# Out:
# Gradient and intercept 1.0316 -858.6563
# R-squared 0.9638330625
# p-value 0.0
# Gradient and intercept 1.3314 -3459.4312
# R-squared 0.9952456644
# p-value 0.0
# Gradient and intercept 0.8574 8.5261
# R-squared 0.9775276900000001
# p-value 0.0
# Gradient and intercept 0.8796 -146.9145
# R-squared 0.9999600004
# p-value 0.0
# Gradient and intercept 1.2351 138.1116
# R-squared 0.9985205476000001
# p-value 0.0
# Gradient and intercept 1.5577 -938.6613
# R-squared 0.9958642849
# p-value 0.00011

# %%
zd = d.copy()
uaclrs = ['#642667', '#623412', '#A6192E', '#65665C', '#719949', '#007681', '#D45D00']
plt.figure(figsize=(16,10))

i = 0
for k in zd.keys():
    #error = np.random.normal(0.1, 0.02, size=y.shape)
    x = np.arange(0,100000)
    y = zd[k]['Gradient'] * x
    plt.plot(x, y, uaclrs[i], label=k, lw=2)
    i+=1

plt.ylabel("Snowdrift Volume m$^3$")
plt.xlabel("Snowdrift Area m$^2$")
leg = plt.legend(loc=2, prop={'size': 24}, frameon=1)
frame = leg.get_frame()
frame.set_facecolor('#EFDBB2')

plt.savefig('../figs/snowdrift_class_area_volume_linreg_all_set_yint0.png',
            dpi=300, bbox_inches='tight')

# %%
# Out:
# {'watertrack': {'x': 0     23636.367493
#   1      9069.760465
#   2     27802.663732
#   3      4386.975592
#   4     43782.341710
#   5      7795.842571
#   6     22701.693592
#   7     25218.646397
#   8     16317.898185
#   9      8373.906097
#   13    41565.969655
#   6      7921.861710
#   7      1071.781596
#   8       820.564506
#   9       516.307417
#   10      480.205013
#   11      653.361839
#   12     2094.562699
#   13     2067.689014
#   14     3515.386899
#   15     3344.353098
#   16     2684.323332
#   Name: Drift Area [m^2], dtype: float64, 'y': 0     18053.440430
#   1      7044.636963
#   2     30428.813477
#   3      3958.892151
#   4     42064.005859
#   5      7116.265503
#   6     20115.997559
#   7     20053.258301
#   8     15617.073242
#   9      7544.316040
#   13    50394.967773
#   6      7741.488159
#   7       898.682159
#   8       701.224228
#   9       456.935486
#   10      390.102066
#   11      525.005211
#   12     1818.667297
#   13     1754.285461
#   14     3126.443481
#   15     2869.252197
#   16     2338.172363
#   Name: Mean Drift Volume [m^3], dtype: float64, 'Gradient': 1.0316, 'Intercept': 0, 'R Value': 0.98175, 'P Value': 0.0, 'Std. Error': 0.0447},
#  'lake': {'x': 10     35968.611370
#   11     61505.782483
#   12    117563.803948
#   0      27257.666957
#   1       8655.475258
#   2      53484.466847
#   3       5933.886379
#   Name: Drift Area [m^2], dtype: float64, 'y': 10     46102.447266
#   11     81642.132812
#   12    154115.818359
#   0      27982.749512
#   1      10898.175781
#   2      62503.092773
#   3       5779.718628
#   Name: Mean Drift Volume [m^3], dtype: float64, 'Gradient': 1.3314, 'Intercept': 0, 'R Value': 0.99762, 'P Value': 0.0, 'Std. Error': 0.0412},
#  'polygon': {'x': 14     683.959700
#   15    1336.342279
#   16     596.837048
#   17     687.210711
#   18     520.709170
#   19    1383.343875
#   20     747.618608
#   17     791.703969
#   18     245.424693
#   19     477.925480
#   20      70.654292
#   21     265.151388
#   Name: Drift Area [m^2], dtype: float64, 'y': 14     571.446587
#   15    1094.193115
#   16     496.026085
#   17     574.211975
#   18     437.063019
#   19    1206.452362
#   20     663.373627
#   17     835.166153
#   18     243.831131
#   19     406.596069
#   20      57.826538
#   21     210.069111
#   Name: Mean Drift Volume [m^3], dtype: float64, 'Gradient': 0.8574, 'Intercept': 0, 'R Value': 0.9887, 'P Value': 0.0, 'Std. Error': 0.0411},
#  'other': {'x': 21      1885.148867
#   22     35638.282474
#   23     23559.060277
#   29     33535.340011
#   30    319265.066946
#   31    463122.952705
#   Name: Drift Area [m^2], dtype: float64, 'y': 21      2050.903625
#   22     29926.290039
#   23     20665.891113
#   29     29439.032227
#   30    282189.328125
#   31    406252.359375
#   Name: Mean Drift Volume [m^3], dtype: float64, 'Gradient': 0.8796, 'Intercept': 0, 'R Value': 0.99998, 'P Value': 0.0, 'Std. Error': 0.0026},
#  'stream': {'x': 24     2854.650591
#   25     1974.880343
#   26     1718.247005
#   4      8007.543927
#   5      7761.727468
#   27    35131.276996
#   28    30090.367740
#   Name: Drift Area [m^2], dtype: float64, 'y': 24     3207.831299
#   25     2520.354126
#   26     1534.397156
#   4     11366.696289
#   5      9946.673584
#   27    43507.118164
#   28    37004.381836
#   Name: Mean Drift Volume [m^3], dtype: float64, 'Gradient': 1.2351, 'Intercept': 0, 'R Value': 0.99926, 'P Value': 0.0, 'Std. Error': 0.0212},
#  'outcrop': {'x': 22    11967.673989
#   23     6084.587952
#   24     3636.010263
#   25     3572.953522
#   26     1900.606070
#   Name: Drift Area [m^2], dtype: float64, 'y': 22    17688.580322
#   23     8884.340698
#   24     4205.573242
#   25     4389.458374
#   26     2448.003906
#   Name: Mean Drift Volume [m^3], dtype: float64, 'Gradient': 1.5577, 'Intercept': 0, 'R Value': 0.99793, 'P Value': 0.00011, 'Std. Error': 0.0579}}

# %%
regdf = pd.DataFrame.from_dict(d, orient='index').sort_values('Gradient')
regdf.Gradient.plot.bar(yerr = regdf['Std. Error'])

# %%
# to retreive shape properties - can do this later if useful
# not relevant at the moment 7/25/19

from skimage.measure import label, regionprops
from skimage.color import label2rgb
from skimage.morphology import binary_dilation
import matplotlib.patches as mpatches

src = rasterio.open('drift_masks/hv_drifts_rasterized.tif')
arr = src.read(1)
msk = (arr > -1).astype(int)
be_msk = binary_dilation(msk)

# %%
label_image = label(be_msk, connectivity=2, background=0)
areas = []
eccs = []
orientations = []
ctrxs = []
ctrys = []

for region in regionprops(label_image):
    areas.append(region.area)
    eccs.append(region.eccentricity)
    orientations.append(region.orientation)
    ctrxs.append(region.centroid[1] + 421000)
    ctrys.append(7678000 - region.centroid[0])
    

df = pd.DataFrame([areas,eccs,orientations,ctrxs, ctrys])

# %%
shapedf = df.T
shapedf.columns = ['area', 'eccentricity', 'orientation', 'x', 'y']
shapedf.sort_values('x', inplace=True)
shapedf.head(3)

# %%
hv['gdfctrx'] = [int(x) for x in hv.geometry.centroid.x]
hv_copy = hv.sort_values('gdfctrx')

#hv_copy
hv_copy.head(3)

# %%
hv_copy['orientation'] = shapedf['orientation']
hv_copy['eccentricity'] = shapedf['eccentricity']

# %%
shapedf['drift_type'] = hv_copy.drift_type

# %%
sns.catplot(x="drift_type", y="eccentricity", data=shapedf)

# %%
gdf_ctr_x = [int(x) for x in hv.geometry.centroid.x]
gdf_ctr_y = [int(y) for y in hv.geometry.centroid.y]
rprops_ctrx = [c[1] + 421000 for c in ctrs]
rprops_ctry = [7678000 - c[0] for c in ctrs]

# %%
xdelt = np.sort(gdf_ctr_x) - np.sort(rprops_ctrx)
ydelt = np.sort(gdf_ctr_y) - np.sort(rprops_ctry)
np.sqrt(xdelt**2 + ydelt**2)
